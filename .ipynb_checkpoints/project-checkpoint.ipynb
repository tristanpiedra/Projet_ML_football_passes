# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functions import *
from Scores import *
from create_dataframe import *
from create_dataframe_regression import * 
from logistic_regression import *
import time
import warnings
warnings.filterwarnings("ignore")
from Random_forest import *
from GradientBoosting import *
from logistic_regression_l2 import * 
#from logistic_regression_optimise import *

# %%
dfreg = pd.read_csv("dataframe_regression.csv")

# %%
dfreg
# Out:
#         Unnamed: 0  sender_id  receiver_id  receveur_potentiel  passe  \
# 0                0         26           18                   1      0
# 1                1         11           14                   1      0
# 2                2          4           10                   1      0
# 3                3         12            7                   1      0
# 4                4         15           24                   1      0
# 5                5         26           18                   1      0
# 6                6          2            1                   1      1
# 7                7         26           18                   1      0
# 8                8         14            7                   1      0
# 9                9         18           21                   1      0
# 10              10         14           10                   1      0
# 11              11         10            9                   1      0
# 12              12         16           18                   1      0
# 13              13         18           21                   1      0
# 14              14          2            4                   1      0
# 15              15         25           18                   1      0
# 16              16          3            5                   1      0
# 17              17         24           25                   1      0
# 18              18          4            8                   1      0
# 19              19         21           20                   1      0
# 20              20         27           18                   1      0
# 21              21         22           18                   1      0
# 22              22          9           12                   1      0
# 23              23         13            3                   1      0
# 24              24         28           26                   1      0
# 25              25         23           16                   1      0
# 26              26         23           15                   1      1
# 27              27         21           23                   1      0
# 28              28         18           20                   1      0
# 29              29          2            4                   1      0
# ...            ...        ...          ...                 ...    ...
# 140516      140516         17           27                  14      0
# 140517      140517         25           18                  14      0
# 140518      140518          3            8                  14      0
# 140519      140519          6            8                  14      0
# 140520      140520          8           13                  14      0
# 140521      140521         15           26                  14      0
# 140522      140522          6            7                  14      0
# 140523      140523          5           11                  14      0
# 140524      140524          3            1                  14      0
# 140525      140525         24           18                  14      0
# 140526      140526         23           24                  14      0
# 140527      140527          2            4                  14      0
# 140528      140528         23           27                  14      0
# 140529      140529         27           20                  14      0
# 140530      140530         13            2                  14      0
# 140531      140531         20           15                  14      0
# 140532      140532          3            5                  14      0
# 140533      140533         24           20                  14      0
# 140534      140534         10            3                  14      0
# 140535      140535          5            8                  14      0
# 140536      140536         14           10                  14      0
# 140537      140537         11           12                  14      0
# 140538      140538         25           22                  14      0
# 140539      140539          9            8                  14      0
# 140540      140540          8           10                  14      0
# 140541      140541          7           11                  14      0
# 140542      140542         17           16                  14      0
# 140543      140543         16           27                  14      0
# 140544      140544         27           21                  14      0
# 140545      140545          3            1                  14      0
#
#         passe_id  score1_distance         score2         score3  \
# 0              1      2392.822601    2392.822601    2392.822601
# 1              2      1198.540779    2098.540779    2098.540779
# 2              3      1290.155029    2190.155029    2190.155029
# 3              4       600.083328    1500.083328    1500.083328
# 4              5    100000.000000  100000.000000  100000.000000
# 5              6      7481.797912    7481.797912    7481.797912
# 6              7      1218.277472    1218.277472    1218.277472
# 7              8      5307.522963    5307.522963    5307.522963
# 8              9      3259.831284    3259.831284    3259.831284
# 9             10      2875.621672    2875.621672    2875.621672
# 10            11      1004.987562    1004.987562    1004.987562
# 11            12      3004.080558    3904.080558    3904.080558
# 12            13      1211.486690    1211.486690    1211.486690
# 13            14       514.003891    1414.003891    1414.003891
# 14            15      1033.924562    1933.924562    1933.924562
# 15            16      3815.783013    3815.783013    3815.783013
# 140523                717.007671               854.400375
# 140524               1977.725967              2249.644416
# 140525                329.848450               370.135110
# 140526                300.166620              1016.366076
# 140527                457.930126              1723.513853
# 140528                997.647232              1004.241007
# 140529                222.036033               523.927476
# 140530                668.879660              1414.390328
# 140531                192.353841              1001.848292
# 140532                681.175455               982.700361
# 140533                490.407993               529.528092
# 140534               1075.406900              1154.859299
# 140535                733.893725              1463.215637
# 140536                454.532727               682.641927
# 140537               2523.529275              2779.946043
# 140538                120.830460               520.864666
# 140539                 92.195445               984.885780
# 140540                951.892851              1694.520581
# 140541               1230.040650              2351.276249
# 140542                382.753184               395.979797
# 140543                822.253002               900.777442
# 140544                310.161248               552.268051
# 140545                 58.309519               572.800140
#
#         distance_ligne_passe  adversaire_dans_cone  Direction_Passe
# 0                1393.417129                     0                1
# 1                 147.178972                     1                1
# 2                   4.883134                     1                1
# 3                  11.498403                     1                1
# 4                   0.000000                     0                0
# 5                  80.074336                     1                1
# 6                  97.432648                     0                1
# 7                1303.941603                     0                1
# 8                  15.276864                     1                1
# 9                1595.341990                     0                0
# 10                520.404450                     0                1
# 11                247.663132                     1                1
# 12                521.838172                     0                1
# 13                127.625493                     1                0
# 14                 59.965690                     1                1
# 15               1003.201699                     0                0
# 16                 95.617519                     1                0
# 17                130.330230                     1                1
# 18                180.572148                     0                1
# 19                  0.000000                     1                1
# 20                622.544657                     0                1
# 21                 18.034840                     1                1
# 22               1405.758007                     0                1
# 23                245.212370                     1                0
# 24                429.489429                     0                0
# 25                538.049601                     0                1
# 26                995.563170                     0                1
# 27                 49.159223                     1                1
# 28                106.848392                     1                0
# 29                  0.000000                     1                0
# ...                      ...                   ...              ...
# 140516              0.000000                     1                1
# 140517            103.222984                     0                1
# 140518              1.990074                     1                1
# 140519             10.330543                     1                1
# 140520              0.000000                     1                0
# 140521            280.996307                     1                1
# 140522             42.134519                     1                1
# 140523              0.000000                     1                0
# 140524              0.000000                     1                0
# 140525              0.000000                     1                1
# 140526             35.961140                     1                1
# 140527             52.255004                     1                0
# 140528              0.000000                     1                1
# 140529              0.000000                     1                1
# 140530              0.000000                     1                0
# 140531              0.000000                     1                1
# 140532            214.105358                     1                1
# 140533              0.000000                     1                0
# 140534              0.000000                     1                0
# 140535              0.000000                     1                0
# 140536              0.000000                     0                1
# 140537            200.272717                     1                0
# 140538              0.000000                     1                1
# 140539             19.391449                     1                1
# 140540             46.620448                     1                0
# 140541              0.000000                     1                0
# 140542              0.000000                     1                1
# 140543            954.523178                     0                1
# 140544             44.538262                     1                1
# 140545             48.552162                     1                0
#
# [140546 rows x 17 columns]

# %%
PasFaite=dfreg[dfreg['passe']==0]
Faite=dfreg[dfreg['passe']==1]
np.sum(Faite['adversaire_dans_cone'])
# Out:
# 3162

# %%
dfregOverSample10=pd.concat([dfreg,Faite,Faite,Faite,Faite,Faite,Faite,Faite,Faite,Faite,Faite])
dfregOverSample10.to_csv("dataframe_regression_OverSamp.csv")
# Out:
# 110429

# %%
tous_scores, moyenne_scores , matrices_coefs = regression_logistique_OverSamp (10, 0.7)
tous_scores
# Out:
# ['receiver_id', 'receveur_potentiel', 'passe', 'passe_id', 'score1_distance', 'score2', 'score3', 'score4', 'premiere_distance_receveur', 'seconde_distance_receveur', 'distance_ligne_passe', 'adversaire_dans_cone', 'Direction_Passe']
# array([0.35325365, 0.36918991, 0.35856574, 0.35922975, 0.35823373,
#        0.35258964, 0.3502656 , 0.34296149, 0.36387782, 0.35358566])

# %%
df=pd.read_csv("passes.csv")
df=df.replace(np.nan, 100000)
dfligne=df.iloc[40]
imageC=image(dfligne,True)
plt.imshow(imageC)
# Out:
# 255 642
# 62 649
# 528 718
# 90 729
# 80 818
# 317 552
# 291 328
# 159 525
# 215 865
# 443 843
# 5 811
# 319 1015
# 112 709
# 265 872
# 142 775
# 75 846
# 249 760
# 400 698
# 194 578
# 397 876
# 218 864
# 44 785

# %% [markdown]
# <font color='blue'>
# On regarde ce que nous renvoie notre fonction directionPasse

# %%
for i in range(10):
    ligne = df.iloc[i]
    sender = df.iloc[i,2]
    receiver = df.iloc[i,3]
    SenderX,SenderY=df.iloc[i,3+sender],df.iloc[i,31+sender]
    ReceiverX,ReceiverY=df.iloc[i,3+receiver],df.iloc[i,31+receiver]
    xmin,xmax,ymin,ymax = -5250, 5250, -3400, 3400
    print(DirectionPasse(ligne))
    plt.scatter(SenderX,SenderY, color='red')
    plt.scatter(ReceiverX,ReceiverY, color='blue')
    plt.xlim(xmin,xmax)
    plt.ylim(ymin,ymax)
    plt.show()
# Out:
# Backward
# Forward
# Forward
# Forward
# Forward
# Backward
# Forward
# Backward
# Forward
# Backward

# %% [markdown]
# <font color='blue'>
# Cela semble marcher

# %% [markdown]
# <font color='blue'>
#   test taux de réussite score1

# %%
reussite1 = np.mean(df["predic1"]==df["receiver_id"])
reussite1
# Out:
# 0.331507122223329

# %% [markdown]
# <font color='blue'>
#     score2

# %%
reussite2 = np.mean(df["predic2"]==df["receiver_id"])
reussite2
# Out:
# 0.39645383006275525

# %% [markdown]
# <Font color='blue'>
#  score3

# %%
reussite3 = np.mean(df["predic3"]==df["receiver_id"])
reussite3
# Out:
# 0.39685227612311985

# %% [markdown]
# <font color='blue'>
#     score4

# %%
reussite4 = np.mean(df["predic4"]==df["receiver_id"])
reussite4
# Out:
# 0.3831058870405419

# %% [markdown]
# <font color = blue>
# Ici on crée le dataframe pour la régression logistique

# %%
dfreg
# Out:
#         Unnamed: 0  sender_id  receiver_id  receveur_potentiel  passe  \
# 0                0         26           18                   1      0
# 1                1         11           14                   1      0
# 2                2          4           10                   1      0
# 3                3         12            7                   1      0
# 4                4         15           24                   1      0
# 5                5         26           18                   1      0
# 6                6          2            1                   1      1
# 7                7         26           18                   1      0
# 8                8         14            7                   1      0
# 9                9         18           21                   1      0
# 10              10         14           10                   1      0
# 11              11         10            9                   1      0
# 12              12         16           18                   1      0
# 13              13         18           21                   1      0
# 14              14          2            4                   1      0
# 15              15         25           18                   1      0
# 16              16          3            5                   1      0
# 17              17         24           25                   1      0
# 18              18          4            8                   1      0
# 19              19         21           20                   1      0
# 20              20         27           18                   1      0
# 21              21         22           18                   1      0
# 22              22          9           12                   1      0
# 23              23         13            3                   1      0
# 24              24         28           26                   1      0
# 13                127.625493                     1                0
# 14                 59.965690                     1                1
# 15               1003.201699                     0                0
# 16                 95.617519                     1                0
# 17                130.330230                     1                1
# 18                180.572148                     0                1
# 19                  0.000000                     1                1
# 20                622.544657                     0                1
# 21                 18.034840                     1                1
# 22               1405.758007                     0                1
# 23                245.212370                     1                0
# 24                429.489429                     0                0
# 25                538.049601                     0                1
# 26                995.563170                     0                1
# 27                 49.159223                     1                1
# 28                106.848392                     1                0
# 29                  0.000000                     1                0
# ...                      ...                   ...              ...
# 140516              0.000000                     1                1
# 140517            103.222984                     0                1
# 140518              1.990074                     1                1
# 140519             10.330543                     1                1
# 140520              0.000000                     1                0
# 140521            280.996307                     1                1
# 140522             42.134519                     1                1
# 140523              0.000000                     1                0
# 140524              0.000000                     1                0
# 140525              0.000000                     1                1
# 140526             35.961140                     1                1
# 140527             52.255004                     1                0
# 140528              0.000000                     1                1
# 140529              0.000000                     1                1
# 140530              0.000000                     1                0
# 140531              0.000000                     1                1
# 140532            214.105358                     1                1
# 140533              0.000000                     1                0
# 140534              0.000000                     1                0
# 140535              0.000000                     1                0
# 140536              0.000000                     0                1
# 140537            200.272717                     1                0
# 140538              0.000000                     1                1
# 140539             19.391449                     1                1
# 140540             46.620448                     1                0
# 140541              0.000000                     1                0
# 140542              0.000000                     1                1
# 140543            954.523178                     0                1
# 140544             44.538262                     1                1
# 140545             48.552162                     1                0
#
# [140546 rows x 17 columns]

# %% [markdown]
# <font color='blue'>
#  ICI ON REGARDE NOS RESULTATS DE LA REGRESSION LOGISTIQUE L1

# %%
x_lrl1, y_lrl1, z_lrl1, h_lrl1, proba_lrl1, table_lrl1 = regression_logistique (10, 0.7)

# %%
x_lrl1
# Out:
# array([0.4252988 , 0.42629482, 0.42098274, 0.4186587 , 0.41832669,
#        0.42065073, 0.41699867, 0.41467463, 0.42164675, 0.41600266])

# %%
plt.boxplot(x_lrl1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x229f068f8d0>,
#   <matplotlib.lines.Line2D at 0x229f068fc18>],
#  'caps': [<matplotlib.lines.Line2D at 0x229f068ff60>,
#   <matplotlib.lines.Line2D at 0x229f06982e8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x229f068f5c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x229f0698630>],
#  'fliers': [<matplotlib.lines.Line2D at 0x229f0698978>],
#  'means': []}

# %%
#moyenne des resultats
y_lrl1
# Out:
# 0.4199535192563081

# %%
plt.bar(range(9), h_lrl1)
# Out:
# <BarContainer object of 9 artists>

# %%
#distribution des probas
plt.bar(np.arange(len(proba_lrl1[:,1])), proba_lrl1[:,1])
# Out:
# <BarContainer object of 42168 artists>

# %%
table_lrl1
# Out:
# passe        0       1
# row_0
# 0      39066.2  2933.4
# 1         89.8    78.6

# %%
#CALCUL DU RECALL, LA METRIQUE QUE L'ON VA COMPARER APRES L'OVERSAMPLING

recall = table_lrl1.iloc[1][1] / (table_lrl1.iloc[1][1] + table_lrl1.iloc[0][1])
recall
# Out:
# 0.02453519256308101

# %% [markdown]
# <font color='blue'>
#  ICI ON REGARDE NOS RESULTATS DE LA REGRESSION LOGISTIQUE L2

# %%
x_lrl2, y_lrl2, z_lrl2, h_lrl2, proba_lrl2 = regression_logistique_l2(10, 0.7)

# %%
x_lrl2
# Out:
# array([0.4123506 , 0.42297477, 0.40737052, 0.40537849, 0.4252988 ,
#        0.42463479, 0.41699867, 0.40903054, 0.42928287, 0.4000664 ])

# %%
plt.boxplot(x_lrl2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ef7e98a0f0>,
#   <matplotlib.lines.Line2D at 0x1ef7e98a438>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ef7e98a780>,
#   <matplotlib.lines.Line2D at 0x1ef7e98aac8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ef7e9b4d68>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ef7e98ae10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ef7e9bd198>],
#  'means': []}

# %%
#moyenne des resultats
y_lrl2
# Out:
# 0.41533864541832666

# %%
#moyenne des coeffs
plt.bar(range(9), h_lrl2)
# Out:
# <BarContainer object of 9 artists>

# %%
#distribution des probas
plt.bar(np.arange(len(proba_lrl2[:,1])), proba_lrl2[:,1])
# Out:
# <BarContainer object of 42168 artists>

# %% [markdown]
# <font color='blue'>
#  ICI ON REGARDE NOS RESULTATS DE LA Random Forest

# %%
x_rf, y_rf, z_rf, h_rf, proba_rf, table_rf = RandomForest (10, 0.7)

# %%
x_rf
# Out:
# array([0.43824701, 0.43525896, 0.43459495, 0.43857902, 0.43492696,
#        0.44223108, 0.42430279, 0.4252988 , 0.43027888, 0.43525896])

# %%
plt.boxplot(x_rf)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x191451c49b0>,
#   <matplotlib.lines.Line2D at 0x191451c4dd8>],
#  'caps': [<matplotlib.lines.Line2D at 0x191451c4eb8>,
#   <matplotlib.lines.Line2D at 0x191451d9668>],
#  'boxes': [<matplotlib.lines.Line2D at 0x191451c4470>],
#  'medians': [<matplotlib.lines.Line2D at 0x191451d9a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x191451d9eb8>],
#  'means': []}

# %%
#moyenne des resultats
y_rf
# Out:
# 0.4338977423638778

# %%
#coeffs
plt.bar(range(9),h_rf)
# Out:
# <BarContainer object of 9 artists>

# %%
#distribution des probas
plt.bar(np.arange(len(proba_rf[:,1])), proba_rf[:,1])
# Out:
# <BarContainer object of 42168 artists>

# %% [markdown]
# <font color = 'blue'>
#     Ici on regarde les résutats du gradient boosting

# %%
x_gb, y_gb, z_gb, h_gb, proba_gb, table_gb = GradientBoosting (10, 0.7)
# Out:
# ['Unnamed: 0', 'sender_id', 'receiver_id', 'receveur_potentiel', 'passe', 'passe_id', 'score1_distance', 'score2', 'score3', 'score4', 'premiere_distance_receveur', 'seconde_distance_receveur', 'premiere_distance_sender', 'seconde_distance_sender', 'distance_ligne_passe', 'adversaire_dans_cone', 'Direction_Passe']

# %%
x_gb
# Out:
# array([0.42430279, 0.42430279, 0.43990704, 0.42895086, 0.43227092,
#        0.42563081, 0.43857902, 0.42994688, 0.4309429 , 0.42463479])

# %%
plt.boxplot(x_gb)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ef0360da20>,
#   <matplotlib.lines.Line2D at 0x1ef0360dd68>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ef036120f0>,
#   <matplotlib.lines.Line2D at 0x1ef03612438>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ef0360d710>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ef03612780>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ef03612ac8>],
#  'means': []}

# %%
#moyenne des resultats
y_gb
# Out:
# 0.4299468791500664

# %%
#coeffs
plt.bar(range(9),h_gb)
# Out:
# <BarContainer object of 9 artists>

# %%
#distribution des probas
plt.bar(np.arange(len(proba_gb[:,1])), proba_gb[:,1])
# Out:
# <BarContainer object of 42168 artists>

# %% [markdown]
# <font color = 'blue'>
# Ici on compare toutes les méthodes entre elles avec les boxplots

# %%
df = np.zeros((10,4))
df[:,0] = x_lrl1
df[:,1] = x_lrl2
df[:,2] = x_rf
df[:,3] = x_gb
dataframe_method = pd.DataFrame(df, columns = ["lrl1", "lrl2", "rf", "gb"])
dataframe_method.boxplot(return_type = 'dict')
plt.show()

# %% [markdown]
# <font color = 'blue'>
# Maintenant on regarde ce que cela donne en centrant les variables quantitatives.

# %% [markdown]
# <font color = 'blue'>
# regression l1 :

# %%
x_lrl1, y_lrl1, z_lrl1, h_lrl1, proba_lrl1, table_lrl1 = regression_logistique (10, 0.7)

# %%
y_lrl1
# Out:
# 0.4120517928286852

# %%
plt.boxplot(x_lrl1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e4c0ca76a0>,
#   <matplotlib.lines.Line2D at 0x2e4c0ca79e8>],
#  'caps': [<matplotlib.lines.Line2D at 0x2e4c0ca7d30>,
#   <matplotlib.lines.Line2D at 0x2e4c0cc10b8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2e4aff2f3c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e4c0cc1400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e4c0cc1748>],
#  'means': []}

# %%
plt.bar(range(9), h_lrl1)
# Out:
# <BarContainer object of 9 artists>

# %%
table_lrl1
# Out:
# passe        0       1
# row_0
# 0      39064.8  2938.9
# 1         91.2    73.1

# %%
plt.bar(np.arange(len(proba_gb[:,1])), proba_lrl1[:,1])

# %% [markdown]
# <font color ='blue'>
# regression l2

# %%
x_lrl2, y_lrl2, z_lrl2, h_lrl2, proba_lrl2 = regression_logistique_l2 (10, 0.7)

# %%
y_lrl2
# Out:
# 0.41152058432934924

# %%
plt.boxplot(x_lrl2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e4c0de8860>,
#   <matplotlib.lines.Line2D at 0x2e4c0de8ba8>],
#  'caps': [<matplotlib.lines.Line2D at 0x2e4c0de8ef0>,
#   <matplotlib.lines.Line2D at 0x2e4c0df5278>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2e4c0de8550>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e4c0df55c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e4c0df5908>],
#  'means': []}

# %%
plt.bar(range(9), h_lrl2)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.bar(np.arange(len(proba_gb[:,1])), proba_lrl2[:,1])

# %% [markdown]
# <font color ='blue'>
# random forest

# %%
x_rf, y_rf, z_rf, h_rf, proba_rf = RandomForest (10, 0.7)

# %%
y_rf
# Out:
# 0.4317065073041168

# %%
plt.boxplot(x_rf)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e4c13778d0>,
#   <matplotlib.lines.Line2D at 0x2e4c1377c88>],
#  'caps': [<matplotlib.lines.Line2D at 0x2e4c1377fd0>,
#   <matplotlib.lines.Line2D at 0x2e4c13812e8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2e4c1377780>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e4c1381630>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e4c1381978>],
#  'means': []}

# %%
plt.bar(range(9), h_rf)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.bar(np.arange(len(proba_gb[:,1])), proba_rf[:,1])

# %% [markdown]
# <font color = 'blue'>
# gradient boosting

# %%
x_gb, y_gb, z_gb, h_gb, proba_gb = GradientBoosting (10, 0.7)
# Out:
# ['Unnamed: 0', 'sender_id', 'receiver_id', 'receveur_potentiel', 'passe', 'passe_id', 'score1_distance', 'score2', 'score3', 'score4', 'premiere_distance_receveur', 'seconde_distance_receveur', 'premiere_distance_sender', 'seconde_distance_sender', 'distance_ligne_passe', 'adversaire_dans_cone', 'Direction_Passe']

# %%
y_gb
# Out:
# 0.4290836653386454

# %%
plt.boxplot(x_gb)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e4c0f5f5c0>,
#   <matplotlib.lines.Line2D at 0x2e4c0f5f908>],
#  'caps': [<matplotlib.lines.Line2D at 0x2e4c0f5fc50>,
#   <matplotlib.lines.Line2D at 0x2e4c0f5ff98>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2e4c0f5f2b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e4c0f6a320>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e4c0f6a668>],
#  'means': []}

# %%
plt.bar(range(9), h_gb)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.bar(np.arange(len(proba_gb[:,1])), proba_gb[:,1])

# %%
#boxplots pour comparer les méthodes 
df = np.zeros((10,4))
df[:,0] = x_lrl1
df[:,1] = x_lrl2
df[:,2] = x_rf
df[:,3] = x_gb
dataframe_method = pd.DataFrame(df, columns = ["lrl1", "lrl2", "rf", "gb"])
dataframe_method.boxplot(return_type = 'dict')
plt.show()

# %% [markdown]
# <font color = 'blue'>
# Maintenant on regarde avec de l'oversampling

# %%
x_lrl1OV, y_lrl1OV, z_lrl1OV, h_lrl1OV, proba_lrl1OV, table_lrl1OV = regression_logistique_OverSamp (10, 0.7)

# %%
x_lrl2OV, y_lrl2OV, z_lrl2OV, h_lrl2OV, proba_lrl2OV, table_lrl2OV = regression_logistique_L2_OverSamp (10, 0.7)

# %%
x_rfOV, y_rfOV, z_rfOV, h_rfOV, proba_rfOV, table_rfOV = RandomForest_OverSamp (10, 0.7)

# %%
x_gbOV, y_gbOV, z_gbOV, h_gbOV, proba_gbOV = GradientBoosting_OverSamp (10, 0.7)

# %%
x_lrl1OV
# Out:
# array([0.27390438, 0.27954847, 0.27589641, 0.2626162 , 0.26361222,
#        0.27058433, 0.27091633, 0.26660027, 0.27357238, 0.2815405 ])

# %%
plt.boxplot(x_lrl1OV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3ea852cc0>,
#   <matplotlib.lines.Line2D at 0x1b3ea864550>],
#  'caps': [<matplotlib.lines.Line2D at 0x1b3ea864978>,
#   <matplotlib.lines.Line2D at 0x1b3ea864da0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b3ea852b70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b3ea864e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3ea86b630>],
#  'means': []}

# %%
#moyenne des resultats
y_lrl1OV
# Out:
# 0.27187915006640107

# %%
#distribution des probas
plt.bar(np.arange(len(proba_lrl1OV[:,1])), proba_lrl1OV[:,1])
# Out:
# <BarContainer object of 42168 artists>

# %%
table_lrl1OV
# Out:
# passe        0       1
# row_0
# 0      39060.4  2938.1
# 1         95.6    73.9

# %%
#CALCUL DU RECALL, LA METRIQUE QUE L'ON VA COMPARER APRES L'OVERSAMPLING

recallOV = table_lrl1OV.iloc[1][1] / (table_lrl1OV.iloc[1][1] + table_lrl1OV.iloc[0][1])
recallOV
# Out:
# 0.02453519256308101

# %% [markdown]
# <font color='blue'>
#  ICI ON REGARDE NOS RESULTATS DE LA REGRESSION LOGISTIQUE L2 Oversamplé

# %%
x_lrl2OV
# Out:
# array([0.27390438, 0.27191235, 0.27357238, 0.27755644, 0.312749  ,
#        0.27191235, 0.30478088, 0.27589641, 0.29847278, 0.2626162 ])

# %%
plt.boxplot(x_lrl2OV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a237209d68>,
#   <matplotlib.lines.Line2D at 0x2a2372195f8>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a237219a20>,
#   <matplotlib.lines.Line2D at 0x2a237219e48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a237209c18>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a237219f28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a2372276d8>],
#  'means': []}

# %%
#moyenne des resultats
y_lrl2OV
# Out:
# 0.28233731739707835

# %%
#moyenne des coeffs
plt.bar(range(9), h_lrl2OV)
# Out:
# <BarContainer object of 9 artists>

# %%
#distribution des probas
plt.bar(np.arange(len(proba_lrl2OV[:,1])), proba_lrl2OV[:,1])
# Out:
# <BarContainer object of 42168 artists>

# %% [markdown]
# <font color='blue'>
#  ICI ON REGARDE NOS RESULTATS DE LA Random Forest OV

# %%
x_rfOV
# Out:
# array([0.39342629, 0.39010624, 0.38213811, 0.39608234, 0.38479416,
#        0.39309429, 0.38545817, 0.37383798, 0.38678619, 0.38346614])

# %%
plt.boxplot(x_rfOV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a2377be470>,
#   <matplotlib.lines.Line2D at 0x2a2377e8f60>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a23781a630>,
#   <matplotlib.lines.Line2D at 0x2a2378422b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a2377a9be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a23786ca20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a237893da0>],
#  'means': []}

# %%
#moyenne des resultats
y_rfOV
# Out:
# 0.3869189907038512

# %%
#coeffs
plt.bar(range(9),h_rfOV)
# Out:
# <BarContainer object of 9 artists>

# %%
#distribution des probas
plt.bar(np.arange(len(proba_rfOV[:,1])), proba_rfOV[:,1])
# Out:
# <BarContainer object of 42168 artists>

# %% [markdown]
# <font color = 'blue'>
#     Ici on regarde les résutats du gradient boosting Oversampled

# %%
x_gbOV
# Out:
# array([0.40504648, 0.39243028, 0.39840637, 0.39541833, 0.39110226,
#        0.39873838, 0.39143426, 0.39342629, 0.37682603, 0.3997344 ])

# %%
plt.boxplot(x_gbOV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a23dd55908>,
#   <matplotlib.lines.Line2D at 0x2a23e000eb8>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a23e2b6ac8>,
#   <matplotlib.lines.Line2D at 0x2a23e51beb8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a23d9f23c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a23e7d2ac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a23ea873c8>],
#  'means': []}

# %%
#moyenne des resultats
y_gbOV
# Out:
# 0.3942563081009296

# %%
#coeffs
plt.bar(range(9),h_gbOV)
# Out:
# <BarContainer object of 9 artists>

# %%
#distribution des probas
plt.bar(np.arange(len(proba_gbOV[:,1])), proba_gbOV[:,1])
# Out:
# <BarContainer object of 42168 artists>

# %% [markdown]
# <font color = 'blue'>
# Ici on compare toutes les méthodes entre elles avec les boxplots

# %%
df = np.zeros((10,4))
df[:,0] = x_lrl1OV
df[:,1] = x_lrl2OV
df[:,2] = x_rfOV
df[:,3] = x_gbOV
dataframe_method = pd.DataFrame(df, columns = ["lrl1OV", "lrl2OV", "rfOV", "gbOV"])
dataframe_method.boxplot(return_type = 'dict')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3bd6861b33f5> in <module>()
#       1 df = np.zeros((10,4))
#       2 df[:,0] = x_lrl1OV
# ----> 3 df[:,1] = x_lrl2OV
#       4 df[:,2] = x_rfOV
#       5 df[:,3] = x_gbOV
#
# NameError: name 'x_lrl2OV' is not defined

# %% [markdown]
# <font color = 'blue'>
# Maintenant on regarde ce que cela donne en centrant les variables quantitatives et en oversamplant.

# %% [markdown]
# <font color = 'blue'>
# regression l1 :

# %%
x_lrl1OVC, y_lrl1OVC, z_lrl1OVC, h_lrl1OVC, proba_lrl1OVC, table_lrl1OVC = regression_logistique_OverSamp (10, 0.7, True)

# %%
y_lrl1OVC
# Out:
# 0.3680278884462152

# %%
plt.boxplot(x_lrl1OVC)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3eac95668>,
#   <matplotlib.lines.Line2D at 0x1b3eac95a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x1b3eac95eb8>,
#   <matplotlib.lines.Line2D at 0x1b3eac95f98>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b3eac95128>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b3eac9c748>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3eac9cb70>],
#  'means': []}

# %%
plt.bar(range(9), h_lrl1OVC)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-ec9e23718771> in <module>()
# ----> 1 plt.bar(range(9), h_lrl1OVC)
#
# NameError: name 'h_lrl1OVC' is not defined

# %%
table_lrl1OVC
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-fb899832e31a> in <module>()
# ----> 1 table_lrl1OVC
#
# NameError: name 'table_lrl1OVC' is not defined

# %%
plt.bar(np.arange(len(proba_gbOVC[:,1])), proba_lrl1OVC[:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-430d6030faad> in <module>()
# ----> 1 plt.bar(np.arange(len(proba_gbOVC[:,1])), proba_lrl1OVC[:,1])
#
# NameError: name 'proba_gbOVC' is not defined

# %% [markdown]
# <font color ='blue'>
# regression l2

# %%
x_lrl2OVC, y_lrl2OVC, z_lrl2OVC, h_lrl2OVC, proba_lrl2OVC, table_lrl1OVC = regression_logistique_L2_OverSamp (10, 0.7, True)

# %%
y_lrl2OVC
# Out:
# 0.349070385126162

# %%
plt.boxplot(x_lrl2OVC)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a2619f96a0>,
#   <matplotlib.lines.Line2D at 0x2a261cb06d8>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a25e904898>,
#   <matplotlib.lines.Line2D at 0x2a25b649e10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a26166c518>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a25aa3fa58>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a25b503e10>],
#  'means': []}

# %%
plt.bar(range(9), h_lrl2OVC)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.bar(np.arange(len(proba_lrl2OVC[:,1])), proba_lrl2OVC[:,1])
# Out:
# <BarContainer object of 42168 artists>

# %% [markdown]
# <font color ='blue'>
# random forest

# %%
x_rfOVC, y_rfOVC, z_rfOVC, h_rfOVC, proba_rfOVC = RandomForest_OverSamp (10, 0.7, True)

# %%
y_rfOVC
# Out:
# 0.3664010624169987

# %%
plt.boxplot(x_rfOVC)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a27fc6f6a0>,
#   <matplotlib.lines.Line2D at 0x2a27fed3d68>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a201300160>,
#   <matplotlib.lines.Line2D at 0x2a201566c50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a27ecd64e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a201862390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a201b0dc50>],
#  'means': []}

# %%
plt.bar(range(9), h_rfOVC)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.bar(np.arange(len(proba_gbOVC[:,1])), proba_rfOVC[:,1])

# %% [markdown]
# <font color = 'blue'>
# gradient boosting

# %%
x_gbOVC, y_gbOVC, z_gbOVC, h_gbOVC, proba_gbOVC = GradientBoosting_OverSamp (10, 0.7, True)

# %%
y_gbOVC
# Out:
# 0.36241699867197874

# %%
plt.boxplot(x_gbOVC)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a213267160>,
#   <matplotlib.lines.Line2D at 0x2a2134ccc50>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a2137c8390>,
#   <matplotlib.lines.Line2D at 0x2a213a75c50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a212eda390>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a213b0e6a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a219072080>],
#  'means': []}

# %%
plt.bar(range(9), h_gbOVC)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.bar(np.arange(len(proba_gb[:,1])), proba_gb[:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-2a9645b58141> in <module>()
# ----> 1 plt.bar(np.arange(len(proba_gb[:,1])), proba_gb[:,1])
#
# NameError: name 'proba_gb' is not defined

# %%
#boxplots pour comparer les méthodes 
df = np.zeros((10,3))
df[:,0] = x_lrl2OVC
#df[:,1] = x_lrl2
df[:,1] = x_rfOVC
df[:,2] = x_gbOVC
dataframe_method = pd.DataFrame(df, columns = ["lrl2OVC", "rfOVC", "gbOVC"])
dataframe_method.boxplot(return_type = 'dict')
plt.show()
